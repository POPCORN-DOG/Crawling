# %%
import requests
import warnings 
from bs4 import BeautifulSoup

warnings.filterwarnings(action='ignore')

# %%
url_sample = 'http://news.daum.net'
url = 'https://news.daum.net/breakingnews/'
source = requests.get(url,verify=False).text
soup = BeautifulSoup(source,"lxml")
soup2 = soup.select('.tab_nav.tab_nav2 > li > a')
for url2 in soup2:
    source1 = requests.get(url_sample+url2['href'],verify=False).text
    soup3 = BeautifulSoup(source1, "lxml")
    soup4 = soup3.select('.box_subtab')
    soup4

# %%
soup3
# Out:
# <!DOCTYPE html>
# <html class="os_unknown none unknown version_0 " lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer"/>
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="전체뉴스" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>전체뉴스 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/af6ba72/common.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/af6ba72/news.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/af6ba72/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
url = 'https://news.daum.net/breakingnews/'

headers = {
    'User-Agent':'Mozilla/5.0'
}
https://news.daum.net/breakingnews/society
headers2 = {
    'Referer':'https://news.daum.net/breakingnews/',
    'User-Agent':'Mozilla/5.0'
}
    
url_sample = 'http://news.daum.net'
resp = requests.get(url,headers=headers,verify=False)
soup = BeautifulSoup(resp.text,'lxml')
soup2 = soup.select('.tab_nav.tab_nav2 > li > a')
for href in soup2[1:]:
    resp2 = requests.get(url_sample+href['href'], headers=headers2,verify=False)
    soup3 = BeautifulSoup(resp2.text,'lxml')
    soup4 = soup3.select('.tab_sub2.tab_social> li > a')

# %%
url_sample+href['href']
# Out:
# 'http://news.daum.net/breakingnews/botnews'
