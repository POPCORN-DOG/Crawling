# %%
import requests
import json
import pandas as pd
import warnings

from pandas import DataFrame

pd.set_option("display.max_rows", None , "display.max_columns", None)
warnings.filterwarnings(action='ignore')

# %%
def wizely(count='1'):
    url = 'https://review-api.wiselycompany.com/api/1.0/review/elasticSearchGetReviewList.do'

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
    }

    data = {
        'page': '1',
        'rgid': '1',
        'perpage': str(count),
        'keywords':'' 
    }

    resp = requests.post(url,headers=headers,data=data, verify=False).text
    jj = json.loads(resp)
    return jj

# %%
df = DataFrame(wizely(wizely()['Pagination']['TotalCount'])['ReviewList'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30998 entries, 0 to 30997
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   RID           30998 non-null  int64
#  1   UNID          30998 non-null  int64
#  2   FullName      30998 non-null  object
#  3   AgeGroup      30998 non-null  object
#  4   ItemID        0 non-null      object
#  5   OrderID       0 non-null      object
#  6   RGID          30998 non-null  int64
#  7   Point         30998 non-null  int64
#  8   Contents      30998 non-null  object
#  9   IsVisible     30998 non-null  object
#  10  AdminUNID     30998 non-null  int64
#  11  Comment       0 non-null      object
#  12  Version       30998 non-null  int64
#  13  ProviderName  30998 non-null  object
#  14  ModifiedDate  1116 non-null   object
#  15  RegDate       30998 non-null  object
#  16  RN            30998 non-null  int64
#  17  Attachments   30998 non-null  object
# dtypes: int64(7), object(11)
# memory usage: 4.3+ MB

# %%
df.head()
# Out:
#      RID    UNID FullName AgeGroup ItemID OrderID  RGID  Point  \
# 0  39079    3290      김*림      30대   None    None     1      5
# 1  39078  814643      신*욱      50대   None    None     1      5
# 2  39077  510711      김*도      50대   None    None     1      2
# 3  39076  547094      장*규      20대   None    None     1      5
# 4  39074  814928      김*성      40대   None    None     1      5
#
#                                             Contents IsVisible  AdminUNID  \
# 0  면도기날 쉐이빙젤  한2년 1년반 정도 정기배송으로 쓰고있는데   면도기가 연견부위...         Y          0
# 1         기존에 쓰던제품인데 신랑,아들이 좋다고 해서  면도날만 재구매 했어요..\n         Y          0
# 2  꼬리부분 무게잡아주는 역할을 하는듯한데 빠지네요.\n이건 기본적인 실수인지 교체를 ...         Y          0
# 3            무가감이 있고 스무스해서 좋음. 면도기집(?)도 줘서 휴대도 편리할듯!         Y          0
# 4                  배송도 빠르고 면도시  뜨김없이 아주 깔끔하게  잘 됩니다.         Y          0
#
#   Comment  Version ProviderName ModifiedDate                        RegDate  \
# 0    None        2   WISELY-2.0         None  2021-03-01T05:55:29.000+00:00
# 1    None        2   WISELY-2.0         None  2021-03-01T03:24:54.000+00:00
# 2    None        2   WISELY-2.0         None  2021-03-01T02:20:28.000+00:00
# 3    None        2   WISELY-2.0         None  2021-03-01T01:06:23.000+00:00
# 4    None        2   WISELY-2.0         None  2021-03-01T01:03:49.000+00:00
#
#    RN Attachments
# 0   0          []
# 1   0          []
# 2   0          []
# 3   0          []
# 4   0          []

# %%
df.to_csv('wizely.csv',sep=',',encoding='utf-8-sig')
